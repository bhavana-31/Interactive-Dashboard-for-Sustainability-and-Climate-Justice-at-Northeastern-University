# %%
# Process one pdf:

# %%
import pdfplumber
import csv
import re
import os

# %%
def find_sentences(text, keyword):
    # Use word boundaries around the keyword to match it as a whole word
    pattern = r'([^.]*?\b' + re.escape(keyword) + r'\b[^.]*\.)'
    sentences = re.findall(pattern, text, re.IGNORECASE)
    return "\n".join(sentences)

# %%
def extract_crn(text):
    # Match the first occurrence of a 5-digit number
    match = re.search(r'\b\d{5}\b', text)
    return match.group(0) if match else ''

# %%
def extract_course(text):
    # Match a pattern of 3 alphabets followed by a space, dash, or parentheses (optional space), then 4 digits
    match = re.search(r'\b[A-Za-z]{3}[\s\-()]*\d{4}\b', text)
    return match.group(0).replace('(', '').replace(')', '').strip() if match else ''

# %%
### Combining all this into one function
## Input -> one pdf path
## Output -> open csv file and edit it

# %%
def process_pdf(pdf_path,keywords,csv_path):
    text = ''
    # Open the PDF file
    with pdfplumber.open(pdf_path) as pdf:
        # Iterate through each page
        for page in pdf.pages:
            # Extract text from the page
            text = text + page.extract_text()
            
    # Extract the crn
    crn = extract_crn(pdf_path)
    course = extract_course(pdf_path)
    
    
    with open(csv_path, mode='a', newline='', encoding='utf-8') as csv_file:
        writer = csv.DictWriter(csv_file, fieldnames=['course','crn', 'keyword', 'isKeywordPresent', 'sentence'])
        
        # Iterate through each keyword and check if it's in the text
        for keyword in keywords:
            is_present = keyword.lower() in text.lower()
            sentences = find_sentences(text, keyword) if is_present else ''
            writer.writerow({
                'course' : course,
                'crn': crn ,
                'keyword': keyword,
                'isKeywordPresent': is_present,
                'sentence': sentences
            })
        
    return csv_path

# %%
## Process just one pdf

pdf_path = '/Users/manoh/Downloads/ALY6070.21136.202325.pdf'
csv_path = 'keywords_check.csv'
keywords = keywords = [
        'Climate', 'Ecologic', 'Ecological', 'Environment', 'Environmental', 'Environmentalism',
        'Fossil Fuel', 'Global Warming', 'Natural', 'Nature', 'Resilience', 'Resilient',
        'Sustainability', 'Sustainable', 'Energy', 'Renewable', 'Solar', 'Wind',
        'Environmental', 'Alternative Transportation', 'Biodiversity', 'Conservation',
        'Consumption', 'Contamination', 'Deforestation', 'Eco-conscious', 'Ecoliteracy',
        'Ecosystem', 'Green building', 'Greenhouse', 'Land management', 'Marine', 'Native species',
        'Pollution', 'Preservation', 'Recycling', 'Waste', 'Water', 'Wildlife', 'Land Use',
        'Social Justice', 'Disparities', 'Equality', 'Equitable', 'Food security', 'Food system',
        'Food waste', 'Human rights', 'Hunger', 'Inequalities', 'Inequity', 'Poverty', 'Racial',
        'Racism', 'Reproductive rights', 'Social change', 'Justice'
    ]


process_pdf(pdf_path,keywords,csv_path)
# Out:
# 'keywords_check.csv'

# %%
import os
import pdfplumber
from pdfminer.pdfparser import PDFSyntaxError

def process_all_pdfs(folder_path, keywords, csv_path):
    # Check if the CSV file already exists and has content
    write_header = not os.path.exists(csv_path) or os.stat(csv_path).st_size == 0
    
    # Write the header if the file is newly created or empty
    if write_header:
        with open(csv_path, mode='w', newline='', encoding='utf-8') as csv_file:
            writer = csv.DictWriter(csv_file, fieldnames=['course', 'crn', 'keyword', 'isKeywordPresent', 'sentence'])
            writer.writeheader()

    for root, dirs, files in os.walk(folder_path):
        for filename in files:
            if filename.lower().endswith('.pdf'):
                pdf_path = os.path.join(root, filename)
                try:
                    print(f"Processing {pdf_path}...")
                    process_pdf(pdf_path, keywords, csv_path)
                except PDFSyntaxError as e:
                    print(f"Error processing {pdf_path}: {e}. Skipping this file.")

# %%
folder_path = '/Users/manoh/Downloads/OneDrive_3_2-14-2024'
keywords = keywords = [
        'Climate', 'Ecologic', 'Ecological', 'Environment', 'Environmental', 'Environmentalism',
        'Fossil Fuel', 'Global Warming', 'Natural', 'Nature', 'Resilience', 'Resilient',
        'Sustainability', 'Sustainable', 'Energy', 'Renewable', 'Solar', 'Wind',
        'Environmental', 'Alternative Transportation', 'Biodiversity', 'Conservation',
        'Consumption', 'Contamination', 'Deforestation', 'Eco-conscious', 'Ecoliteracy',
        'Ecosystem', 'Green building', 'Greenhouse', 'Land management', 'Marine', 'Native species',
        'Pollution', 'Preservation', 'Recycling', 'Waste', 'Water', 'Wildlife', 'Land Use',
        'Social Justice', 'Disparities', 'Equality', 'Equitable', 'Food security', 'Food system',
        'Food waste', 'Human rights', 'Hunger', 'Inequalities', 'Inequity', 'Poverty', 'Racial',
        'Racism', 'Reproductive rights', 'Social change', 'Justice'
    ]
csv_path = 'keywords_check.csv'

with open(csv_path, mode='w', newline='', encoding='utf-8') as csv_file:
            writer = csv.DictWriter(csv_file, fieldnames=['course', 'crn', 'keyword', 'isKeywordPresent', 'sentence'])
            writer.writeheader()
            
process_all_pdfs(folder_path, keywords, csv_path)
# Out:
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7207.20565.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/LDR7980.20197.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/DGM6168.21815.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CED6910.20405.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/GST6504.21046.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/GST6550.20579.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CMN6000.21066.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CED6010.20451.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6102.20598.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6205.20839.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/LDR6100.20064.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/RGA6463.21702.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CMN6090.20066.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6910.20179.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/HRM6042.20655.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7226.20568.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CMN6050.20646.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CED6120.20775.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/RGA6380.21194.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/RGA6410.21302.202452.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/ITC6020.20950.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/GST6109.20402.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7310.21533.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6145.21080.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6050.20172.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7295.20670.202425.pdf...
# Error processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7295.20670.202425.pdf: No /Root object! - Is this really a PDF?. Skipping this file.
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6205.20263.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDUC1111.30889.202430.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CED6040.20454.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM5900.20875.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7504.21534.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/RGA6001.21708.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6329.21543.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CMN6090.20937.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/GST6102.20221.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/LDR6441.20205.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/GST6101.20024.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7276.20213.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6005.20873.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CED6011.21541.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CED6031.21040.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6866.20261.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/GST6340.21044.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CMN6005.21426.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CED6220.20458.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6610.21248.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6025.20166.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/FIN6102.21529.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM5900.20126.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/GST6340.21043.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/GST6920.21740.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7295.21433.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/ALY6015.20463.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/GST6700.21047.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CMN6050.20461.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/ALY6070.20354.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7218.20567.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CMN6910.21071.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6175.20616.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6204.20561.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6910.20141.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6075.20736.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6710.20347.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6229.20687.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7294.20992.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/ITC6010.20260.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6025.20898.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6910.20150.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM5900.21576.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EAI6010.20601.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/NPM6120.20041.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7310.20992.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/LDR6150.20191.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/ALY6130.21668.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7316.20831.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7225.20593.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CED6010.20556.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CMN6020.21457.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/GST6210.20222.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/LDR7980.20198.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7314.20830.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/SIA6983.21101.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6335.21342.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM5900.20525.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM5900.21573.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6640.20620.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/LDR6135.20036.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/LDR6150.20283.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/LDR6110.20033.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7227.20571.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/GST6100.20806.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6107.20020.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6051.20018.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6210.21583.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/ITC6000.20609.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6319.20174.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/LDR6150.20224.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/GST6102.20134.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM5900.20528.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/NTR6110.20046.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CMN6100.20169.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7213.20211.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/DGM6168.21401.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6101.20599.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7226.20570.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CMN6080.20008.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6234.20688.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CED6250.20673.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7310.21532.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7260.21540.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/GST6590.20273.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CED6020.20452.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/DGM6268.20377.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/RGA6202.20266.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7313.20830.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6426.20021.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/NTR6148.20146.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7510.21316.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/GST6504.20575.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/GST6100.20133.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/ITC6400.21700.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/LDR6100.20029.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6002.20560.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7294.20795.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CED6020.20557.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CMN6025.20647.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CED6983.20993.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CMN6110.20011.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6025.20499.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6075.21177.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7207.20564.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/ALY6050.21137.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CED6031.20558.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CED6050.20455.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/NTR6200.20145.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CMN6020.20218.202425..pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6135.20207.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/BTC6210.20874.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6558.21692.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/DGM6285.20171.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6610.21612.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM5900.20731.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CED6220.20559.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7225.20590.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6135.70323.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7258.20212.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM5900.20069.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7243.21720.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/HRM6015.20391.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6558.21348.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/ITC6035.20504.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6558.20153.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/HRM6072.20941.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CMN6910.20067.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CMN6010.20004.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM5900.21572.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7294.20692.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/NTR6105.20727.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6025.20732.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6910.21233.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CMN6000.21674.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6015.20143.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/GST6327.20274.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6210.21582.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6910.20914.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6410.21547.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6015.21609.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/GST6360.21045.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PBR6135.20645.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/GST6920.20178.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6225.20127.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7219.20689.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/SIA6170.21714.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7219.20690.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/HRM6050.20721.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7317.21527.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7218.20566.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/NPM6220.20583.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/HRM6020.20705.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6086.20019.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6336.21545.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6205.20562.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6334.20872.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM5900.21577.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7226.20594.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6217.20563.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/DGM6410.21019.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/CMN6940.20431.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/ALY6050.21138.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU7225.20592.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6310.21688.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDUC5570.32108.202430.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6222.20686.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/PJM6075.21178.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/BTC6210.20780.202425.pdf...
# Processing /Users/manoh/Downloads/OneDrive_3_2-14-2024/EDU6558.20769.202425.pdf...
